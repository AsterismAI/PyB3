# %% [markdown]
# # Python B3 Outputter
#
# Kerry N. Wood (kerry.wood@jhuapl.edu)
#
# - this came out of the AstroStandards ctypes work `asctypes`
# - that code compares AstroStandards output with the Python output, so we won't do reverse engineering here
# - this just "productizes" the code

# %%
import os
import glob
import sys
import astropy.coordinates
import astropy.units as u
import astropy.time
from datetime import datetime, timedelta
import json
import numpy as np

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# ## B3 outputter
#
# - this is really decoupled from above
# - if you pass in the labeled data appropriately, this should just work

# %%
ds50epoch = astropy.time.Time( datetime.strptime( '1949-12-31T00:00:00', "%Y-%m-%dT%H:%M:%S") )

def ds50ToATime( flt ):
    try: return astropy.time.Time( ds50epoch.jd + flt , format='jd' )
    except Exception as e: 
        print('ds50ToATime: cannot parse input: {}'.format(str(e)))
        return None

def ds50ToDateTime( flt ):
    '''
    given the days-since-1950 float, return a datetime
     "YYDDDHHMMSS.SSS"
     '''
    return ds50ToATime( flt ).datetime
# Out:
# /Users/woodkn1/PY37/lib/python3.7/site-packages/erfa/core.py:155: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   ErfaWarning)

# %%
def B3_float_field( val, left, right ):
    '''
    given a float, we need a structured output that puts the decimal at a specific column
    total field length = left + right
    further, B3's deal with negatives with a character mapping to keep the field-lengths constant (see below)
    '''
    if val < 0: neg = True
    else: neg = False
    l,r = str(np.abs(val)).split('.')
    l = l[-left:].rjust(left,'0')
    r = r[:right].ljust(right,'0')
    if not neg: return l + r
    if l[0] == '0' : return '-' + l[1:] + r
    if l[0] == '1' : return 'J' + l[1:] + r
    if l[0] == '2' : return 'K' + l[1:] + r
    if l[0] == '3' : return 'L' + l[1:] + r
    if l[0] == '4' : return 'M' + l[1:] + r
    if l[0] == '5' : return 'N' + l[1:] + r
    if l[0] == '6' : return 'O' + l[1:] + r
    if l[0] == '7' : return 'P' + l[1:] + r
    if l[0] == '8' : return 'Q' + l[1:] + r
    if l[0] == '9' : return 'R' + l[1:] + r
    
def makeDate( datetm ): return datetm.strftime('%y%j%H%M%S%f')[:14]
    
def makeCommon( obdata, datetm=None, classification='U' ):
    ts      = list(' '*76)  # init the string
    ts[0]   = 'U'
    ts[1:6] = '{:05d}'.format( int(obdata['XA_OBS_SATNUM'] ) )
    ts[6:9] = '{:03d}'.format( int(obdata['XA_OBS_SENNUM'] ) )
    # we can pass in a datetime, or use what's in the struct (mostly this will be used for non A.S. data)
    if datetm == None:
        timedatetime = ds50ToDateTime( obdata['XA_OBS_DS50UTC'])
        ts[9:23] = makeDate( timedatetime )
    else:
        ts[9:23] = makeDate( datetm )
    return ts
    
def makeEl( el ): return B3_float_field( el, 2, 4)

def makeRA( dec ):
    '''
    Each hour is 360∘/24=15∘. 
    Each minute of time is 15∘/60=15′, i.e. 15 arcminutes. 
    Each second of time is 15′/60=15′′, i.e. 15 arcseconds.
    '''
    dec = (dec + 360) % 360  # lock it to [0,360] and the values below should not overflow
    hours  = int( dec / 15 )
    frac   = dec - (15 * hours)
    minut  = int( frac / 0.25 )
    frac -= 0.25 * minut 
    secs   =  frac * 86400./360.
    secsS  = '{:04.1f}'.format( secs ).replace('.','')
    frac -= secs * 0.25/60
    return "{:02d}{:02d}{}".format( hours, minut, secsS )

def makeRange( rangeval ):
    '''
    return the range field and the exponent location
    '''
    exp = int(np.log10( rangeval ))
    expval = exp-1  # this is the exponent mapping (valid ranges are 99.99999 to 9,999,999, so 0=10^1)
    if expval < 0 or expval > 5: raise
    return str(rangeval).replace('.','').ljust(7,'0')[0:7], str(expval)

def fortran9p3( flt ): 
    '''
    this is used for type 9 EFG sensor locations
    '''
    if flt < 0: neg = True
    else : neg = False
    l,r = str(np.abs(flt)).split('.')
    l = l[-6:].rjust(6,'0')
    r = r[-3:].ljust(3,'0')
    if neg : return '-' + l[1:] + r
    return '+' + l[1:] + r

# %%
# ------------------------------------  TYPE 1 ---------------------------------------
def maketype1( obdata, datetm=None ):
    ts = makeCommon( obdata, datetm=datetm )
    ts[23:29] = makeEl( obdata['XA_OBS_ELORDEC'])
    ts[30:37] = B3_float_field( obdata['XA_OBS_AZORRA'], 3,4)
    ts[74] = '1'
    ts[75] = '0'
    return ''.join(ts)

# ------------------------------------  TYPE 2 ---------------------------------------
def maketype2( data, datetm=None ):
    '''
    4 - Elevation, azimuth, range, range rate, elevation rate, azimuth rate, rate acceleration
    types 2,3,4 are a subset of this...
    
    '''
    ts = makeCommon(data, datetm=datetm) 
    ts[23:29] = makeEl( data['XA_OBS_ELORDEC'])
    ts[30:37] = B3_float_field( data['XA_OBS_AZORRA'],3,4)
    rgval, rgexp = makeRange(data['XA_OBS_RANGE'])  # this carves out the exponent...
    ts[38:45] = rgval
    ts[45]    = rgexp
    ts[74] = '2'
    ts[75] = '0'
    return ''.join(ts)


# ------------------------------------  TYPE 3 ---------------------------------------
def maketype3( data, datetm=None ):
    '''
    4 - Elevation, azimuth, range, range rate, elevation rate, azimuth rate, rate acceleration
    types 2,3,4 are a subset of this...
    
    '''
    ts = makeCommon(data, datetm=datetm) 
    ts[23:29] = makeEl( data['XA_OBS_ELORDEC'])
    ts[30:37] = B3_float_field( data['XA_OBS_AZORRA'],3,4)
    rgval, rgexp = makeRange(data['XA_OBS_RANGE'])  # this carves out the exponent...
    ts[38:45] = rgval
    ts[45]    = rgexp
    ts[47:54] = B3_float_field( data['XA_OBS_RANGERATE'],2,5)  
    ts[74] = '3'
    ts[75] = '0'
    return ''.join(ts)

# ------------------------------------  TYPE 4 ---------------------------------------
def maketype4( data, datetm=None ):
    '''
    4 - Elevation, azimuth, range, range rate, elevation rate, azimuth rate, rate acceleration
    types 2,3,4 are a subset of this...
    
    '''
    ts = makeCommon(data, datetm=datetm) 
    ts[23:29] = makeEl( data['XA_OBS_ELORDEC'])
    ts[30:37] = B3_float_field( data['XA_OBS_AZORRA'],3,4)
    rgval, rgexp = makeRange(data['XA_OBS_RANGE'])  # this carves out the exponent...
    ts[38:45] = rgval
    ts[45]    = rgexp
    ts[47:54] = B3_float_field( data['XA_OBS_RANGERATE'],2,5)  
    ts[55:60] = B3_float_field( data['XA_OBS_ELRATE'],1,4) 
    ts[61:66] = B3_float_field( data['XA_OBS_AZRATE'],1,4) 
    ts[67:72] = B3_float_field( data['XA_OBS_RANGEACCEL'],1,4)
    ts[74] = '4'
    ts[75] = '0'
    return ''.join(ts)

# ------------------------------------  TYPE 5 ---------------------------------------
def maketype5( data, datetm=None ):
    ts = makeCommon( data, datetm=datetm )
    ts[23:29] = B3_float_field( data['XA_OBS_ELORDEC'], 2, 4)
    ts[30:37] = makeRA( data['XA_OBS_AZORRA'])
    ts[74] = '5'
    ts[75] = '0'
    return ''.join(ts)

# ------------------------------------  TYPE 6 ---------------------------------------
def maketype6( data, datetm=None ):
    ts = makeCommon( data, datetm=datetm )
    rgval, rgexp = makeRange(data['XA_OBS_RANGE'])  # this carves out the exponent...
    ts[38:45] = rgval
    ts[45]    = rgexp
    ts[74] = '6'
    ts[75] = '0'
    return ''.join(ts)

# ------------------------------------  TYPE 9 ---------------------------------------
def maketype9( data, datetm=None ):
    ts = makeCommon( data, datetm=datetm )
    ts[23:29] = makeEl( data['XA_OBS_ELORDEC'])
    ts[30:37] = makeRA( data['XA_OBS_AZORRA'])
    ts[38:45] = '0000000'
    ts[46:55] = fortran9p3( data['XA_OBS_POSX'] ) 
    ts[55:64] = fortran9p3( data['XA_OBS_POSY'] ) 
    ts[64:73] = fortran9p3( data['XA_OBS_POSZ'] ) 
    ts[74] = '9'
    ts[75] = '0'
    return ''.join(ts)

def b3_dispatcher( data ):
    if data['XA_OBS_OBSTYPE'] == 1: return maketype1( data  )
    if data['XA_OBS_OBSTYPE'] == 2: return maketype2( data  )
    if data['XA_OBS_OBSTYPE'] == 3: return maketype3( data  )
    if data['XA_OBS_OBSTYPE'] == 4: return maketype4( data  )
    if data['XA_OBS_OBSTYPE'] == 5: return maketype5( data  )
    if data['XA_OBS_OBSTYPE'] == 6: return maketype6( data  )
    if data['XA_OBS_OBSTYPE'] == 9: return maketype9( data  )

# %%
# %run B3_parser.ipynb
# Out:
# <style>.container { width:95% !important; }</style>
# U2301324298022165241992019037 0633491                                     5 3  100000
# {'obstype': 5, 'classification': 'U', 'sensid': 242, 'satid': 23013, 'date': '1998-01-22T16:52:41.992000', 'el_dec': 1.9037, 'az_ra': 98.45458333333333, 'range': -1.0, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 3}
#
# U2301324298022165305313019171 0634118                                     5 4  100000
# {'obstype': 5, 'classification': 'U', 'sensid': 242, 'satid': 23013, 'date': '1998-01-22T16:53:05.313000', 'el_dec': 1.9171, 'az_ra': 98.54916666666666, 'range': -1.0, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 4}
#
# U2301324298022165333660019112 0634391                                     5 4  100000
# {'obstype': 5, 'classification': 'U', 'sensid': 242, 'satid': 23013, 'date': '1998-01-22T16:53:33.660000', 'el_dec': 1.9112, 'az_ra': 98.66291666666666, 'range': -1.0, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 4}
#
# U2301324298022165355724019139 0635005                                     5 4  100000
# {'obstype': 5, 'classification': 'U', 'sensid': 242, 'satid': 23013, 'date': '1998-01-22T16:53:55.724000', 'el_dec': 1.9139, 'az_ra': 98.75208333333332, 'range': -1.0, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 4}
#
# U2301324298022165418307019159 0635225                                     5 5  100000
# {'obstype': 5, 'classification': 'U', 'sensid': 242, 'satid': 23013, 'date': '1998-01-22T16:54:18.307000', 'el_dec': 1.9159, 'az_ra': 98.84374999999999, 'range': -1.0, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 5}
#
# U2301324198023184158917024486 0747228                                     5 3  100000
# {'obstype': 5, 'classification': 'U', 'sensid': 241, 'satid': 23013, 'date': '1998-01-23T18:41:58.917000', 'el_dec': 2.4486, 'az_ra': 116.845, 'range': -1.0, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 3}
#
# U2301324198023184221967024510 0747452                                     5 4  100000
# {'obstype': 5, 'classification': 'U', 'sensid': 241, 'satid': 23013, 'date': '1998-01-23T18:42:21.967000', 'el_dec': 2.451, 'az_ra': 116.93833333333333, 'range': -1.0, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 4}
#
# U2301324198023184244275024530 0748068                                     5 4  100000
# {'obstype': 5, 'classification': 'U', 'sensid': 241, 'satid': 23013, 'date': '1998-01-23T18:42:44.275000', 'el_dec': 2.453, 'az_ra': 117.02833333333334, 'range': -1.0, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 4}
#
# U2301324198023184308984024556 0748309                                     5 5  100000
# {'obstype': 5, 'classification': 'U', 'sensid': 241, 'satid': 23013, 'date': '1998-01-23T18:43:08.984000', 'el_dec': 2.4556, 'az_ra': 117.12875, 'range': -1.0, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 5}
#
# U2
200000
# {'obstype': 5, 'classification': 'U', 'sensid': 243, 'satid': 20712, 'date': '1998-06-02T00:15:50.975000', 'el_dec': 10.6902, 'az_ra': 348.09458333333333, 'range': -1.0, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 4}
#
# U2071239998153043214146077309 1608711 91202842                            2 3  100000
# {'obstype': 2, 'classification': 'U', 'sensid': 399, 'satid': 20712, 'date': '1998-06-02T04:32:14.146000', 'el_dec': 7.7309, 'az_ra': 160.8711, 'range': 9120.284, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 3}
#
# U2071226098154013252501K52219 1924381                                     5 3  100000
# {'obstype': 5, 'classification': 'U', 'sensid': 260, 'satid': 20712, 'date': '1998-06-03T01:32:52.501000', 'el_dec': -25.2219, 'az_ra': 291.15875, 'range': -1.0, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 3}
#
# U2071226098154013301001K51748 1924557                                     5 4  100000
# {'obstype': 5, 'classification': 'U', 'sensid': 260, 'satid': 20712, 'date': '1998-06-03T01:33:01.100000', 'el_dec': -25.1748, 'az_ra': 291.2320833333333, 'range': -1.0, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 4}
#
# U2071226098154013309001K51306 1925124                                     5 4  100000
# {'obstype': 5, 'classification': 'U', 'sensid': 260, 'satid': 20712, 'date': '1998-06-03T01:33:09.100000', 'el_dec': -25.1306, 'az_ra': 291.3016666666667, 'range': -1.0, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 4}
#
# U2071226098154013317001K50871 1925289                                     5 4  100000
# {'obstype': 5, 'classification': 'U', 'sensid': 260, 'satid': 20712, 'date': '1998-06-03T01:33:17.100000', 'el_dec': -25.0871, 'az_ra': 291.37041666666664, 'range': -1.0, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 4}
#
# U2071226098154013325001K50430 1925454                                     5 5  100000
# {'obstype': 5, 'classification': 'U', 'sensid': 260, 'satid': 20712, 'date': '1998-06-03T01:33:25.100000', 'el_dec': -25.043, 'az_ra': 291.43916666666667, 'range': -1.0, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 5}
#
# U2071239998155072536753102123 2070955 10328733                            2 3  100000
# {'obstype': 2, 'classification': 'U', 'sensid': 399, 'satid': 20712, 'date': '1998-06-04T07:25:36.753000', 'el_dec': 10.2123, 'az_ra': 207.0955, 'range': 10328.73, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 3}
#
# U2071239998155073512295208564 1970924 11931463                            2 5  100000
# {'obstype': 2, 'classification': 'U', 'sensid': 399, 'satid': 20712, 'date': '1998-06-04T07:35:12.295000', 'el_dec': 20.8564, 'az_ra': 197.0924, 'range': 11931.46, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 5}
#
# U2071295198155143746070095138 0035210                                     5 3  200000
# {'obstype': 5, 'classification': 'U', 'sensid': 951, 'satid': 20712, 'date': '1998-06-04T14:37:46.700000', 'el_dec': 9.5138, 'az_ra': 8.8375, 'range': -1.0, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 3}
#
# U2071295198155143755289095208 0035303                                     5 4  200000
# {'obstype': 5, 'classification': 'U', 'sensid': 951, 'satid': 20712, 'date': '1998-06-04T14:37:55.289000', 'el_dec': 9.5208, 'az_ra': 8.87625, 'range': -1.0, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 4}
#
# U2071295198155143805410095303 0035403                                     5 4  200000
# {'obstype': 5, 'classification': 'U', 'sensid': 951, 'satid': 20712, 'date': '1998-06-04T14:38:05.410000', 'el_dec': 9.5303, 'az_ra': 8.917916666666667, 'range': -1.0, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 4}
#
# U2071295198155143815441095381 0035503                                     5 4  200000
# {'obstype': 5, 'classification': 'U', 'sensid': 951, 'satid': 20712, 'date': '1998-06-04T14:38:15.441000', 'el_dec': 9.5381, 'az_ra': 8.959583333333335, 'range': -1.0, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 4}
#
# U2071295198155143825328095461 0036003                                     5 4  200000
# {'obstype': 5, 'classification': 'U', 'sensid': 951, 'satid': 20712, 'date': '1998-06-04T14:38:25.328000', 'el_dec': 9.5461, 'az_ra': 9.001249999999999, 'range': -1.0, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 4}
#
# U2071295198155143837270095557 0036123                                     5 5  200000
# {'obstype': 5, 'classification': 'U', 'sensid': 951, 'satid': 20712, 'date': '1998-06-04T14:38:37.270000', 'el_dec': 9.5557, 'az_ra': 9.05125, 'range': -1.0, 'range_rate': -1.0, 'ecfx': 0.0, 'ecfy': 0.0, 'ecfz': 0.0, 'elrate': -1.0, 'azrate': -1.0, 'rangeacc': -1.0, 'site_tag': 0, 'spadoc_tag': None, 'track_position': 5}

# %%
Q = B3s[0].toAstrostdDict()
b3_dispatcher(Q)

for B in B3s:
    print(B.origline)
    print( b3_dispatcher( B.toAstrostdDict() ) )
# Out:
# U2301324298022165241992019037 0633491                                     5 3  100000
# U2301324298022165241992019037 0633491                                     50
# U2301324298022165305313019171 0634118                                     5 4  100000
# U2301324298022165305312019171 0634118                                     50
# U2301324298022165333660019112 0634391                                     5 4  100000
# U2301324298022165333660019112 0634391                                     50
# U2301324298022165355724019139 0635005                                     5 4  100000
# U2301324298022165355724019139 0635005                                     50
# U2301324298022165418307019159 0635225                                     5 5  100000
# U2301324298022165418306019159 0635225                                     50
# U2301324198023184158917024486 0747228                                     5 3  100000
# U2301324198023184158917024486 0747228                                     50
# U2301324198023184221967024510 0747452                                     5 4  100000
